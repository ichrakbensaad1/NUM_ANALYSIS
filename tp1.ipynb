# %% [markdown]
# ![entete.png](data:image/png;base64,...)

# %% [markdown]
# #Exercice1

# %% [markdown]
# ***Exercice 1:***
# On considère le polynôme $p(x) = (x - 1)^6$.
#
# En développant on peut écrire ce même polynôme sous la forme $f(x) = x^6 - 6x^5 + 15x^4 - 20x^3 + 15x^2 - 6x + 1.$
#
# 1) Avec Matlab évaluer $p(x)$ et $f(x)$ pour $x$ allant de $.998$ à $1.002$ en choisissant des pas de $.0001$.
#
# 2) Faire un graphique de $f(x)$ et $p(x)$. Commenter.

# %%
def p(x):
    #définir la fonction polynome  x^2+2x+1
    return x**2+2*x+1

# %%
def prod(x,y):
    ''' Cette fonction effectue le produit de deux nombre
    '''
    return x*y # cett eligne retourne le produit de x et y

# %%
prod(5,6)
# Out:
# 30

# %%
def p1(x):
    ''' p(x)=(x-1)⁶'''
    return (x-1)**6 
def p2(x):
    '''version développer de p(x)'''
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
p1
# Out:
# <function __main__.p1>

# %%
# le calcul de p1(0.998)
print('p1({})={} '.format(0.998,p1(0.998)))
# le calcul de p2(0.998)
print('p2({})={} '.format(0.998,p2(0.998)))
# Out:
# p1(0.998)=6.400000000000034e-17
# p2(0.998)=1.7763568394002505e-15

# %%
p2(3)
# Out:
# 64

# %%
def horner(a,z_0):
  n = len (a)
  result=a[1] 
  for j in range (2,n):
    result = result *z_0+a[j]
  x= result

# %%
def p(x):
    #définir la fonction polynome (x-1)^6
    return (x-1)**6

# %%
def f(x):
    #définir la fonction polynome x.^6 - 6*x.^5 + 15*x.^4 - 20*x.^3 + 15*x.^2 - 6*x + 1
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
T = [1, -6, 15, -20, 15, -6, 1]

for i in range (0.998 ,0.001,1.002):
  print(p(i))

for i in range (0.998 ,0.001,1.002):
  print(f(i))

for i in range  (0.998 ,0.001,1.002):
  print(horner(T,i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5019b3cc2ef6> in <module>()
#       2 T = [1, -6, 15, -20, 15, -6, 1]
#       3
# ----> 4 for i in range (0.998 ,1.002):
#       5   print(p(i))
#       6
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# 2)

# %%
x=[0.998:0.0001:1.002]
plot(x,f(x),'r',x,p(x),'b*')
title ("solution dans [0.998:0.0001:1.002] ");
xlabel ("x");
ylabel ("f(x)");
grid on

# %% [markdown]
# #Exercice 2

# %% [markdown]
# *Exercice 2 :*
#
#  On considère l'équation :$$ f(x)=x^3+x^2-3x-3=0$$1) Dessiner la courbe de $f$ dans l'intervalle $[-2;2]$, puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
#
# 2) Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation $f(x)=0$ avec $eps=0.001$.
#
# 3) Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près.

# %% [markdown]
# **1)**

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
def f(x):
    return x**3+x**2-3*x-3

# %%
T=[-2, 0.1, 2]
TT= np.linspace(-2,2,41)# subdivision de [-2,2] en 40 subdivision ( 41 ponts)

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)

plt.plot(T,f(T))

# %% [markdown]
# -Daprés le graph de $f$ il existe 3 solutions :
#
#
#
#
#
#
# *  $\alpha_1 \in ]-2;-1.5[$
#
# *   $\alpha_2 \in ]-1.5;-0.5[$
# *  $\alpha_3 \in ]1.5;2[$

# %% [markdown]
# #2.2 Version OCTAVE:

# %%
from math import *

# %%
def dicho(a,b,f,n):
    m=(a+b)/2
    err=abs(b-a)
    while (err>n):
      
      if f(m)==0:

        break
      if f(a)*f(m)<0:
        b=m
      else:
        a=m
      m=(a+b)/2
      err=abs(b-a)
      x=m


    
      pass

# %%
x3=dicho(-2,-1.5,f,10)
#x10=dicho(-2,-1.5,f,10)
#x20=dicho(-2,-1.5,f,20)
#print(x3,x10,x20)
print(x3)
# Out:
# None

# %%
print('f(x10)={},f(x20)={}'.format(f(x10),f(x20)))
#fonction pow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-74b2a9669324> in <module>()
# ----> 1 print('f(x10)={},f(x20)={}'.format(f(x10),f(x20)))
#
# <ipython-input-125-13b228a64d71> in <lambda>(x)
# ----> 1 f=lambda x: x**3+x**2-3*x-3
#       2 def dicho(a,b,f,n):
#       3       m=(a+b)/2
#       4       err=abs(b-a)
#       5       while (err>n):
#
# TypeError: unsupported operand type(s) for ** or pow(): 'NoneType' and 'int'

# %% [markdown]
# version tant que qui renvoila solution avec le nombre d'''itération

# %%
def dichow(a,b,f,eps):  
    
    pass

# %%
dichow(-2,-1.5,f,0.0001)

# %% [markdown]
# 3)

# %%
:
f=@(x) x.^3+x.^2-3*x-3
t=linspace(1.7,1.75,100);
subplot(2,2,1)
plot(t,f(t),'r')
grid on
##########################################
t=linspace(1.2,1.4,100);
subplot(2,2,2)
plot(t,f(t),'r')
grid on
##########################################
t=linspace(1.35,1.4,100);
subplot(2,2,3)
plot(t,f(t),'r')
grid on
#########################################
t=linspace(1.365,1.367,100);
subplot(2,2,4)
plot(t,f(t),'r')
grid on

# %%
import numpy as np
np.floor(2.3)
np.ceil(2.3)
# Out:
# 3.0

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
dichow(a,b,f,10**(-p))
#à 10^-8

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dichow(u[0],u[1],f,10**(-3)))
################################################   
print(dichow(-2,-1.5,f,10**(-3)))
print(dichow(-1.5,-0.5,f,10**(-3)))
print(dichow(1.5,2,f,10**(-3)))
# Out:
# None
# None
# None
# None
# None
# None

# %% [markdown]
# -Le nombre d'itération N nécéssaire à la méthode de la dichotomie pour trouver $\alpha$ à $10^{-p}$ prés
#
# $$N \geq E\left(\dfrac{\ln(b-a)+p\ln(10)}{\ln(2)}\right)+1$$

# %%
def nombre_iteration(F , x0 , , tol =1 e -6 ,p) :
2 # Initialisation
3 xn = x0 # premier élément de la suite
4 L = [] # la liste [x_0 , ... x_{n -1}] , pour le moment vide
5
6 # Boucle principale
7 for n in range ( Niter ) : # pas de while dans ce cours !
8 if ... < tol : # Si le critère de convergence est atteint ,
9 return xn , L # on renvoie xn et la liste [x_0 , ... x_{n -1}].
10 L . append ( xn ) # Sinon , on ajoute xn à la liste ,
11 xn = ... # puis on met à jour xn avec la formule d’itération
12 print (" Erreur , l’algorithme n’a pas convergé après ", Niter , " itérations ")
# Out:
#   File "<ipython-input-144-bea483fa7ca2>", line 2
#     def nombre_iteration(F , x0 , ... , tol =1 e -6 , Niter =1000) :
#                                     ^
# SyntaxError: invalid syntax

# %%
a=-2
b=-1.5
ND(5)

# %%
#alpha 1
dichow(-2,-1.5,f,10**(-5))
#à 10^-8

# %% [markdown]
# Méthode graphique pour la recherche de la solution

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# Transformer le code précédent pour trouver desvaleurs approchées des solutions $\alpha_1$, $\alpha_2$ et $\alpha_3$ de l'equation (E)¶
# In [ ]:

# %% [markdown]
# #Exercice 3:

# %% [markdown]
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
#
# 2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
#
# a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
#
# b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
#
# c) $g_3(x)=x-x^3-4x^2+10=x$.
#
# 3) Ecrire puis appliquer une fonction Matlab que l'on appellera pointfixe.m aux trois schémas précédents en prenant >x0=1.5;eps=0.001.
#
# 4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?

# %% [markdown]
# **1)**

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# *2) Justification théorique pour la fonction g1*
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$
#
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
#
# $$x^3+4x^2-10=0$$
#
# $$4x^2=10-x^3$$
#
# $$2x=\sqrt{10-x^3}$$
#
# $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# **Calcul symbolique de la dérivée**

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# **Que pouvez vous conclure à propos des convergences de g1**

# %% [markdown]
# **Justification théoriques pour g2 et g3**
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$
#
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
#
# $$x^3+4x^2-10=0$$$$x^3+4x^2=10$$$$x^2(x+4)=10$$$$x^2=\frac{10}{x+4}$$$$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$
#
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$c) $g(x)=x-x^3-4x^2+10=x$.
#
# $$x^3+4x^2-10=0$$$$x^3+4x^2-10+x-x=0$$$$x^3-4x^2+x-x=10$$$$x^3-4x^2+x=x+10$$$$4x^2+x=x-x^3+10$$$$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# **Etudier théoriquement la convergences de g2 et g3**

# %% [markdown]
# **4)**

# %%
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    pass





    print('pas de convergence avec le nombre d''iteration indique')

# %%
ptfixe(g3,1.5,0.0001,30)
# Out:
# pas de convergence avec le nombre diteration indique

# %% [markdown]
#  **Quelle est la fonction qui donne la convergence la plus rapide ??**

# %% [markdown]
# Donner le nombre d'itération pour chaque méthode convergent e
#
# * g_2$ donne le resultat en ? itérations
# * g_1$ donne le resultat en ?
#
# * g_3$ est - elle convergente?

# %% [markdown]
# #Ecercice 4 :

# %% [markdown]
# 1) On considère la fonction $f(x)=e^{-x}-x$. Ecrire puis appliquer une fonction Matlab que l'on appellera newton.m à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ .
#
# 2) Montrer que l'équation $f(x)=0$ admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de $x0=1$.

# %% [markdown]
# **1)**

# %%
from math import exp
import matplotlib.pyplot as plt
from numpy import linspace

# %%
def newton (a , eps):

  x = a
  y = x - f ( x ) / fprime ( x )
  n = 0
  while (abs( y - x ) > exp) and (n < 50):
      n += 1
      z = y - f ( y ) / dfprime ( y )
  eps = y

# %%
f=lambda x :exp(-x)-x
fprime =lambda x: -exp(-x) -1
T=linspace(0,1,10)
plt.title("solution dans [-2:2] ")
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-ac179bd3dbdd> in <module>()
#       6 plt.ylabel ("f(x)")
#       7 plt.grid(True)
# ----> 8 plt.plot(T,f(T))
#
# <ipython-input-183-ac179bd3dbdd> in <lambda>(x)
# ----> 1 f=lambda x :exp(-x)-x
#       2 fprime =lambda x: -exp(-x) -1
#       3 T=linspace(0,1,10)
#       4 plt.title("solution dans [-2:2] ")
#       5 plt.xlabel("x")
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-210a00580501> in <module>()
#       1 t=np.linspace(0,1,100)
# ----> 2 plot(t,label=f(t))
#
# <ipython-input-170-4fc3701075e4> in <lambda>(x)
# ----> 1 f=lambda x: exp(-x)-x
#       2 fprime =lambda x: -exp(-x) -1
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
newton(1,0.001)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-887f1a16d667> in <module>()
# ----> 1 newton(1,0.001)
#
# <ipython-input-169-16ef60e53afe> in newton(a, eps)
#       4   y = x - f ( x ) / fprime ( x )
#       5   n = 0
# ----> 6   while (abs( y - x ) > exp) and (n < 50):
#       7       n += 1
#       8       z = y - f ( y ) / dfprime ( y )
#
# TypeError: '>' not supported between instances of 'float' and 'builtin_function_or_method'

# %% [markdown]
# **2)**

# %%
newton(1,0.001)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-181-887f1a16d667> in <module>()
# ----> 1 newton(1,0.001)
#
# <ipython-input-169-16ef60e53afe> in newton(a, eps)
#       4   y = x - f ( x ) / fprime ( x )
#       5   n = 0
# ----> 6   while (abs( y - x ) > exp) and (n < 50):
#       7       n += 1
#       8       z = y - f ( y ) / dfprime ( y )
#
# TypeError: '>' not supported between instances of 'float' and 'builtin_function_or_method'
