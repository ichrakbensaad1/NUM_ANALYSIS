# %% [markdown]
# <a href="https://colab.research.google.com/github/ichrakbensaad1/NUM_ANALYSIS/blob/master/tp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![entet.png](data:image/png;base64,...)

# %% [markdown]
# #Ecercice 1:

# %%
from numpy import prod
def prog(x,y,c):
    S = [] 
    n = len(x)
    
    for j in range(n):
        L =[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
        S.append(y[j]*prod(L))
        
    return  sum(S)

# %%
X=[1 ,2 ,3 ,4,-2];
Y=[-1, 0, 2 ,1,3];
for i in X:
    print(prog(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 3.0
# 8

# %% [markdown]
# **Polynome d'interpolation de Lagrange**
#
# Soient $(x_0,y_0), \ldots,(x_k,y_k),\ldots ,(x_n,k_n)$ $n+1$ points deux à deux distincts, le polynôme d'interpolation de Lagrange associés à ces points supports est défini par :$$P_n(x)=\sum_{k=0}^{n-1} y_kL_k(x)$$
#
# avec $L_{0}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{n})}{(x_0-x_1)(x_0-x_2)\ldots(x_0-x_{n})}$ et $L_{k}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{k-1})(x-x_{k+1})\ldots(x_0-x_{n})}{(x_k-x_0)(x_k-x_1)\ldots(x_k-x_{k-1})(x_k-x_{k+1})\ldots(x_k-x_{n})}$ pour $k\in \{1,\ldots,n\}$
#
# 1) Que renvoie la fonction PR lorsqu'on lui déclare x=(x(1),x(2),...,x(n))x=(x(1),x(2),...,x(n)) et y=(y(1),y(2),...,y(n))y=(y(1),y(2),...,y(n)) deux vecteurs de même longueur n et c un nombre réel donné.

# %%
from numpy import prod

def PR(x,y,c):
   S = [] 
   n = len(x)
    
   for j in range(n):
        L =[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
        S.append(y[j]*prod(L))
        
   return  sum(S)

# %%
X=[1, 2, 3, 4]
Y=[-1, 0, 2, 1]
for i in X:
  print(PR(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 10

# %% [markdown]
# 2)Que contient le vecteur LL après la fin de la boucle kk

# %%
x=[1, 2, 3, 4]
y=[-1, 0, 2, 1]

# %%
 S = [] 
 n = len(x)
 for c in (X):
    
  for j in range(n):
      L =[c-xx for xx in x]
      for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
      S.append(y[j]*prod(L))
        
 print (sum(S))
# Out:
# 2.0

# %%
L
# Out:
# [1.0, 1.0, 1.0, 1]

# %% [markdown]
# 3°
# 3) Utiliser cette fonction pour dessiner le graph du polynôme de Lagrange de la fonction $f(x) = \dfrac{1}{1 + x^2}$ aux points $x=[-1:0.1:1]$.

# %%
import matplotlib.pyplot as plt
from numpy import linspace

x=[-1, 0.1, 1]
f=lambda x: 1/(1+x**2)
t=linspace(-1,1,100)
for u in range (1,len(t)):
    pt[u] = PR(x,y,t[u])
plt.title("Courbe de f(x) ")
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)

plt.plot(t,pt,'r',x,y,'bo',t,f(t),'g')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-4705eb4f9abd> in <module>()
#       6 t=linspace(-1,1,100)
#       7 for u in range (1,len(t)):
# ----> 8     pt[u] = PR(x,y,t[u])
#       9 plt.title("Courbe de f(x) ")
#      10 plt.xlabel("x")
#
# IndexError: list assignment index out of range

# %% [markdown]
# 4) On considère la fonction $F$ suivante :$$
# F(h) = \pi -\cos \left(\frac{h}{2}\right) + h \sqrt{1-\left(\frac{h}{2}\right)^2}, \qquad
# h\in [0,2],
# $$et les points d'interpolation $x_i = ih$, $0\leq i\leq n$, avec $ n=20$ et $h=0.1$.
#
# 4.1) Représenter sur un même graphe la fonction $F$ et $p_n$, où $p_n$ est le polynôme d'interpolation de Lagrange de $F$ aux points $x_0,\,\ldots,\,x_n$

# %%
import matplotlib.pyplot as plt
from math import *
from numpy import linspace

x=[0, 2]
f=lambda x: pi-cos(x/2)+x*sqrt(1-(x/2)**2)
t=linspace(-1,1,100)
for u in range (1,len(t)):
    pn[u] = PR(x,y,t[u])
plt.title("Courbe de f(x) ")
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.plot(t,pn,'r',x,y,'bo',t,f(t),'g')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-213ebe85e133> in <module>()
#       7 t=linspace(-1,1,100)
#       8 for u in range (1,len(t)):
# ----> 9     pn[u] = PR(x,y,t[u])
#      10 plt.title("Courbe de f(x) ")
#      11 plt.xlabel("x")
#
# NameError: name 'pn' is not defined

# %% [markdown]
# 2)Tracer la courbe d'erreur (la fonction $F-p_n$). Qu'observer vous.

# %%
import matplotlib.pyplot as plt
from math import *
from numpy import linspace

x=[0, 2]
f=lambda x: pi-cos(x/2)+x*sqrt(1-(x/2)**2)
t=linspace(-1,1,100)
for u in range (1,len(t)):
    pn[u] = PR(x,y,t[u])
plt.title("Courbe de f(x) ")
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.plot(t,f(t)-pn,'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-c3a8a67b86d9> in <module>()
#       7 t=linspace(-1,1,100)
#       8 for u in range (1,len(t)):
# ----> 9     pn[u] = PR(x,y,t[u])
#      10 plt.title("Courbe de f(x) ")
#      11 plt.xlabel("x")
#
# NameError: name 'pn' is not defined

# %% [markdown]
# #Ecercice2:

# %% [markdown]
# **Phenomène de Runge**

# %% [markdown]
# 1) Vérifier que sur $[-5,5]$ le polynôme d'interpolation de Lagrange de la fonction $f$ définie par $f(x)=\displaystyle{\frac{1}{1+x^2}}$, en $N$ points uniformément espacés ne convergent pas correctement aux voisinages de $-1$ et $1$, pour $N=7,8,9,10 ...$

# %%
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np

# %%
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np
N=7
X=linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=linspace(-5,5,1000)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=7")
#####################################################
N=8
X=linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=linspace(-5,5,1000)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=8")
#######################################################
N=9
X=linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X);
p=np.polyfit(X,Y,N-1)
t=linspace(-5,5,1000)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=9")
#######################################################
N=10
X=linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X);
p=np.polyfit(X,Y,N-1)
t=linspace(-5,5,1000)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=10")
# Out:
# Text(0.5, 1.0, 'Interpolation Equidistante avec N=10')

# %% [markdown]
# 2) Les points de Tchebycheff sur un intervalle $[a;b]$ sont définie par :$$x_k=\dfrac{a+b}{2}+\dfrac{a-b}{2}\cos\left(\frac{k-1}{n-1}\pi\right)\hspace{0.5cm} (k=1,..,n: x_1=a:x_n=b)$$
#
# Vérifier que sur $[-5; 5]$ ; l'interpolation polynômiale de $f(x) = \dfrac{1}{1 + x^2}$ ; en $N$ points de Tchebychev est meilleure qu'une interpolation utilisant $N$ points uniforment espacés (on prendra $N=10, 11, 16, 17$).

# %%
from  math import *
def tcheb (a,b,n):
  V=[]
  for k in range (1,n):
    V[k]=(a+b)/2+(a-b)/2*cos((k-1)/(n-1)*pi)
print(tcheb(-5,5,11))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-3cf6cb62430f> in <module>()
#       4   for k in range (1,n):
#       5     V[k]=(a+b)/2+(a-b)/2*cos((k-1)/(n-1)*pi)
# ----> 6 print(tcheb(-5,5,11))
#
# <ipython-input-94-3cf6cb62430f> in tcheb(a, b, n)
#       3   V=[]
#       4   for k in range (1,n):
# ----> 5     V[k]=(a+b)/2+(a-b)/2*cos((k-1)/(n-1)*pi)
#       6 print(tcheb(-5,5,11))
#
# IndexError: list assignment index out of range

# %%
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np
N=10
Xt=tcheb(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(Xt)
p=np.polyfit(Xt,Yt,N-1)

plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=10")
#####################################################
N=11
Xt=tcheb(-5,5,N)
f=lambda x: 1/(1+x**2)
Yt=f(Xt)
p=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,2)
plot(t,f(t),'r',Xt,Yt,'ob', t, polyval(pt,t),'g')
plt.title("Interpolation Equidistante avec N=11")
#######################################################
N=16
Xt=tcheb(-5,5,N)
f=lambda x: 1/(1+x**2)
Yt=f(Xt);
p=np.polyfit(Xt,Yt,N-1)
t=linspace(-5,5,1000)
plt.subplot(2,2,3)
plot(t,f(t),'r',Xt,Yt,'ob', t, polyval(pt,t),'g')
plt.title("Interpolation Equidistante avec N=16")
#######################################################
N=17
Xt=tcheb(-5,5,N)
f=lambda x: 1/(1+x**2)
Yt=f(Xt);
p=np.polyfit(Xt,Yt,N-1)
t=linspace(-5,5,1000)
plt.subplot(2,2,4)
plot(t,f(t),'r',Xt,Yt,'ob', t, polyval(pt,t),'g')
plt.title("Interpolation Equidistante avec N=17")
